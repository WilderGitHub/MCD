# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %% [markdown]
# ## Leemos dataset y tipos de datos

# %%
df = pd.read_csv('kaggle_ecommerce1.csv',encoding='latin1')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32671 entries, 0 to 32670
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   _unit_id             32671 non-null  int64
#  1   relevance            20571 non-null  float64
#  2   relevance:variance   20571 non-null  float64
#  3   product_image        32671 non-null  object
#  4   product_link         32671 non-null  object
#  5   product_price        32671 non-null  object
#  6   product_title        32671 non-null  object
#  7   query                32671 non-null  object
#  8   rank                 32671 non-null  int64
#  9   source               32671 non-null  object
#  10  url                  32671 non-null  object
#  11  product_description  24800 non-null  object
#  12  invoice              32671 non-null  int64
# dtypes: float64(2), int64(3), object(8)
# memory usage: 3.2+ MB

# %% [markdown]
# ### Eliminamos columnas innecesarias

# %%
df.drop(['product_image', 'product_link', 'product_title', 'product_description', 'url'], axis=1, inplace=True)
df
# Out:
#         _unit_id  relevance  relevance:variance product_price          query  \
# 0      711158459       3.67               0.471      $329.98   playstation 4
# 1      711158460       4.00               0.000      $324.84   playstation 4
# 2      711158461       4.00               0.000      $324.83   playstation 4
# 3      711158462       3.67               0.471      $350.00   playstation 4
# 4      711158463       3.33               0.471      $308.00   playstation 4
# ...          ...        ...                 ...           ...            ...
# 32666  713196633        NaN                 NaN      $109.99      snow boots
# 32667  713196634        NaN                 NaN      $175.00      snow boots
# 32668  713196635        NaN                 NaN      $175.00      snow boots
# 32669  713196636        NaN                 NaN      $169.00      snow boots
# 32670  713196637        NaN                 NaN       $39.99      snow boots
#
#        rank    source  invoice
# 0         1      eBay      579
# 1         2      eBay      703
# 2         3      eBay      862
# 3         4      eBay      307
# 4         5      eBay      120
# ...     ...       ...      ...
# 32666    30  Shop.com      397
# 32667    31  Shop.com      674
# 32668    32  Shop.com      475
# 32669    33  Shop.com      856
# 32670    34  Shop.com      148
#
# [32671 rows x 8 columns]

# %% [markdown]
# ### La columna product_price tiene muchos tipos de datos

# %%
df['product_price'].value_counts()
# Out:
# $19.99                503
# $29.99                424
# $39.99                386
# $24.99                352
# $49.99                330
#                      ...
# $154.99 - $398.00       1
# $24.90,Sale $19.67      1
# $37.18                  1
# $8.90                   1
# $80.99 - $93.99         1
# Name: product_price, Length: 11240, dtype: int64

# %% [markdown]
# ### Limpiamos y convertimos el tipo de dato de "object" a "float"

# %%
df["price"]=df['product_price'].str[1:6]
df
# Out:
#         _unit_id  relevance  relevance:variance product_price          query  \
# 0      711158459       3.67               0.471      $329.98   playstation 4
# 1      711158460       4.00               0.000      $324.84   playstation 4
# 2      711158461       4.00               0.000      $324.83   playstation 4
# 3      711158462       3.67               0.471      $350.00   playstation 4
# 4      711158463       3.33               0.471      $308.00   playstation 4
# ...          ...        ...                 ...           ...            ...
# 32666  713196633        NaN                 NaN      $109.99      snow boots
# 32667  713196634        NaN                 NaN      $175.00      snow boots
# 32668  713196635        NaN                 NaN      $175.00      snow boots
# 32669  713196636        NaN                 NaN      $169.00      snow boots
# 32670  713196637        NaN                 NaN       $39.99      snow boots
#
#        rank    source  invoice  price
# 0         1      eBay      579  329.9
# 1         2      eBay      703  324.8
# 2         3      eBay      862  324.8
# 3         4      eBay      307  350.0
# 4         5      eBay      120  308.0
# ...     ...       ...      ...    ...
# 32666    30  Shop.com      397  109.9
# 32667    31  Shop.com      674  175.0
# 32668    32  Shop.com      475  175.0
# 32669    33  Shop.com      856  169.0
# 32670    34  Shop.com      148  39.99
#
# [32671 rows x 9 columns]

# %%
df.drop(['product_price'], axis=1, inplace=True)
df
# Out:
#         _unit_id  relevance  relevance:variance          query  rank  \
# 0      711158459       3.67               0.471  playstation 4     1
# 1      711158460       4.00               0.000  playstation 4     2
# 2      711158461       4.00               0.000  playstation 4     3
# 3      711158462       3.67               0.471  playstation 4     4
# 4      711158463       3.33               0.471  playstation 4     5
# ...          ...        ...                 ...            ...   ...
# 32666  713196633        NaN                 NaN     snow boots    30
# 32667  713196634        NaN                 NaN     snow boots    31
# 32668  713196635        NaN                 NaN     snow boots    32
# 32669  713196636        NaN                 NaN     snow boots    33
# 32670  713196637        NaN                 NaN     snow boots    34
#
#          source  invoice  price
# 0          eBay      579  329.9
# 1          eBay      703  324.8
# 2          eBay      862  324.8
# 3          eBay      307  350.0
# 4          eBay      120  308.0
# ...         ...      ...    ...
# 32666  Shop.com      397  109.9
# 32667  Shop.com      674  175.0
# 32668  Shop.com      475  175.0
# 32669  Shop.com      856  169.0
# 32670  Shop.com      148  39.99
#
# [32671 rows x 8 columns]

# %%
df1=df[df["price"] == "ale $"].index
df1=df.drop(df1)
df2=df1[df1["price"] == "eg:\np"].index
df2=df1.drop(df2)
df3=df2[df2["price"] == "ist:\n"].index
df3=df2.drop(df3)
df3
# Out:
#         _unit_id  relevance  relevance:variance          query  rank  \
# 0      711158459       3.67               0.471  playstation 4     1
# 1      711158460       4.00               0.000  playstation 4     2
# 2      711158461       4.00               0.000  playstation 4     3
# 3      711158462       3.67               0.471  playstation 4     4
# 4      711158463       3.33               0.471  playstation 4     5
# ...          ...        ...                 ...            ...   ...
# 32666  713196633        NaN                 NaN     snow boots    30
# 32667  713196634        NaN                 NaN     snow boots    31
# 32668  713196635        NaN                 NaN     snow boots    32
# 32669  713196636        NaN                 NaN     snow boots    33
# 32670  713196637        NaN                 NaN     snow boots    34
#
#          source  invoice  price
# 0          eBay      579  329.9
# 1          eBay      703  324.8
# 2          eBay      862  324.8
# 3          eBay      307  350.0
# 4          eBay      120  308.0
# ...         ...      ...    ...
# 32666  Shop.com      397  109.9
# 32667  Shop.com      674  175.0
# 32668  Shop.com      475  175.0
# 32669  Shop.com      856  169.0
# 32670  Shop.com      148  39.99
#
# [32103 rows x 8 columns]

# %%
df3['price'] = df3['price'].str.replace(',','')
df3['price']
df3['price'] = df3['price'].astype('float64')
df3['price'].dtype
# Out:
# dtype('float64')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32103 entries, 0 to 32670
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   _unit_id            32103 non-null  int64
#  1   relevance           20229 non-null  float64
#  2   relevance:variance  20229 non-null  float64
#  3   query               32103 non-null  object
#  4   rank                32103 non-null  int64
#  5   source              32103 non-null  object
#  6   invoice             32103 non-null  int64
#  7   price               32103 non-null  float64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 2.2+ MB

# %%
data = [df3["invoice"],df3["query"]]
headers = ["invoice","product"]
dfventas = pd.concat(data, axis=1, keys=headers)
dfventas.head(2)
# Out:
#    invoice        product
# 0      579  playstation 4
# 1      703  playstation 4

# %%
dfventas = dfventas.groupby(['invoice', 'product']).size()
aux = dfventas.unstack(level=-1)
productos = aux.reset_index().fillna(0).set_index('invoice')

def codificar(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1
productos1 = productos.applymap(codificar)
productos1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 999 entries, 1 to 999
# Columns: 264 entries, 16 gb memory card to zippo hand warmer
# dtypes: int64(264)
# memory usage: 2.0 MB

# %%
#productos1.to_csv("borrar.csv", index=False)
#frequent_itemsets = apriori(productos1, min_support=0.009,use_colnames=True)
#reglas = association_rules(frequent_itemsets, metric="lift", min_threshold=3)
#reglas.sort_values(by = "lift", ascending = False).head(3)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-20-60b7a205ab21> in <module>
#       1 #productos1.to_csv("borrar.csv", index=False)
# ----> 2 frequent_itemsets = apriori(productos1, min_support=0.009,use_colnames=True)
#       3 reglas = association_rules(frequent_itemsets, metric="lift", min_threshold=3)
#       4 reglas.sort_values(by = "lift", ascending = False).head(3)
#
# ~\Desktop\MCD\I. 03 Minería de Datos I\Proyecto\mlxtend\frequent_patterns\apriori.py in apriori(df, min_support, use_colnames, max_len, verbose, low_memory)
#     300                     _bools = _bools & (X[:, combin[:, n]] == all_ones)
#     301             else:
# --> 302                 _bools = np.all(X[:, combin], axis=2)
#     303
#     304             support = _support(np.array(_bools), rows_count, is_sparse)
#
# MemoryError: Unable to allocate 45.8 GiB for an array with shape (2050357, 3, 999) and data type int64
