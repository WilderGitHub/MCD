# %%
import numpy as np
import pandas as pd

#import urllib.request

import sklearn
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
#from sklearn.cross_validation import train_test_split
from sklearn.model_selection import train_test_split

from sklearn import metrics
from sklearn.metrics import accuracy_score

# Import LabelEncoder
from sklearn import preprocessing

# %%
dataset = pd.read_csv('Fertility1.csv', sep=";")

# %%
dataset.head()
# Out:
#    season  age Ch_Disease Accident Surg_Int        H_Fever  \
# 0  Summer   32         No      Yes      Yes  Greater th 3m
# 1    Fall   32         No       No       No  Greater th 3m
# 2  Winter   30        Yes       No       No  Greater th 3m
# 3  Spring   31         No       No       No  Greater th 3m
# 4  Spring   30         No      Yes       No  Greater th 3m
#
#            Alcohol_Cons       Smoke  N_Hours    Diag
# 0  Hardly ever or never       Daily        1  Normal
# 1  Several times a week  Occasional        2  Normal
# 2  Several times a week       Never        3  Normal
# 3  Several times a week       Never        3  Normal
# 4           Once a week       Never        3  Normal

# %%
dataset.shape
# Out:
# (100, 10)

# %%
dataset.head()
# Out:
#    season  age Ch_Disease Accident Surg_Int        H_Fever  \
# 0  Summer   32         No      Yes      Yes  Greater th 3m
# 1    Fall   32         No       No       No  Greater th 3m
# 2  Winter   30        Yes       No       No  Greater th 3m
# 3  Spring   31         No       No       No  Greater th 3m
# 4  Spring   30         No      Yes       No  Greater th 3m
#
#            Alcohol_Cons       Smoke  N_Hours    Diag
# 0  Hardly ever or never       Daily        1  Normal
# 1  Several times a week  Occasional        2  Normal
# 2  Several times a week       Never        3  Normal
# 3  Several times a week       Never        3  Normal
# 4           Once a week       Never        3  Normal

# %%
#labelEncoder
le = preprocessing.LabelEncoder()

# Converting string labels into numbers.
dataset['season_cd']=le.fit_transform(dataset.loc[:, 'season'])
dataset['Ch_Disease_cd']=le.fit_transform(dataset.loc[:, 'Ch_Disease'])
dataset['Accident_cd']=le.fit_transform(dataset.loc[:, 'Accident'])
dataset['Surg_Int_cd']=le.fit_transform(dataset.loc[:, 'Surg_Int'])
dataset['H_Fever_cd']=le.fit_transform(dataset.loc[:, 'H_Fever'])
dataset['Alcohol_Cons_cd']=le.fit_transform(dataset.loc[:, 'Alcohol_Cons'])
dataset['Smoke_cd']=le.fit_transform(dataset.loc[:, 'Smoke'])

# %%
dataset.head()
# Out:
#    season  age Ch_Disease Accident Surg_Int        H_Fever  \
# 0  Summer   32         No      Yes      Yes  Greater th 3m
# 1    Fall   32         No       No       No  Greater th 3m
# 2  Winter   30        Yes       No       No  Greater th 3m
# 3  Spring   31         No       No       No  Greater th 3m
# 4  Spring   30         No      Yes       No  Greater th 3m
#
#            Alcohol_Cons       Smoke  N_Hours    Diag  season_cd  \
# 0  Hardly ever or never       Daily        1  Normal          2
# 1  Several times a week  Occasional        2  Normal          0
# 2  Several times a week       Never        3  Normal          3
# 3  Several times a week       Never        3  Normal          1
# 4           Once a week       Never        3  Normal          1
#
#    Ch_Disease_cd  Accident_cd  Surg_Int_cd  H_Fever_cd  Alcohol_Cons_cd  \
# 0              0            1            1           0                1
# 1              0            0            0           0                4
# 2              1            0            0           0                4
# 3              0            0            0           0                4
# 4              0            1            0           0                2
#
#    Smoke_cd
# 0         0
# 1         2
# 2         1
# 3         1
# 4         1

# %%
dataset = dataset.drop(['season', 'Ch_Disease', 'Accident', 'Surg_Int', 'H_Fever', 'Alcohol_Cons', 'Smoke'], axis=1)

# %%
dataset.head()
# Out:
#    age  N_Hours    Diag  season_cd  Ch_Disease_cd  Accident_cd  Surg_Int_cd  \
# 0   32        1  Normal          2              0            1            1
# 1   32        2  Normal          0              0            0            0
# 2   30        3  Normal          3              1            0            0
# 3   31        3  Normal          1              0            0            0
# 4   30        3  Normal          1              0            1            0
#
#    H_Fever_cd  Alcohol_Cons_cd  Smoke_cd
# 0           0                1         0
# 1           0                4         2
# 2           0                4         1
# 3           0                4         1
# 4           0                2         1

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              100 non-null    int64
#  1   N_Hours          100 non-null    int64
#  2   Diag             100 non-null    object
#  3   season_cd        100 non-null    int64
#  4   Ch_Disease_cd    100 non-null    int64
#  5   Accident_cd      100 non-null    int64
#  6   Surg_Int_cd      100 non-null    int64
#  7   H_Fever_cd       100 non-null    int64
#  8   Alcohol_Cons_cd  100 non-null    int64
#  9   Smoke_cd         100 non-null    int64
# dtypes: int64(9), object(1)
# memory usage: 7.9+ KB

# %%
X = dataset.loc[:, dataset.columns != 'Diag']
y = dataset.loc[:, dataset.columns == 'Diag']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0, stratify=y)

# %%
y
# Out:
#        Diag
# 0    Normal
# 1    Normal
# 2    Normal
# 3    Normal
# 4    Normal
# ..      ...
# 95  Altered
# 96  Altered
# 97  Altered
# 98  Altered
# 99  Altered
#
# [100 rows x 1 columns]

# %%
BernNB = BernoulliNB(binarize = 0.1)
BernNB.fit(X_train, y_train)
print(BernNB)
# Out:
# BernoulliNB(binarize=0.1)
# /Users/ofigue/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
y_expect = y_test
y_pred = BernNB.predict(X_test)
print(accuracy_score(y_expect, y_pred))
# Out:
# 0.8666666666666667

# %%
MultiNB = MultinomialNB()
MultiNB.fit(X_train, y_train)
print(MultiNB)
y_pred = MultiNB.predict(X_test)
print(accuracy_score(y_expect, y_pred))
# Out:
# MultinomialNB()
# 0.8666666666666667
# /Users/ofigue/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
GaussNB = GaussianNB()
GaussNB.fit(X_train, y_train)
print(GaussNB)
y_pred = GaussNB.predict(X_test)
print(accuracy_score(y_expect, y_pred))
# Out:
# GaussianNB()
# 0.9
# /Users/ofigue/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
type(y_pred)
# Out:
# numpy.ndarray
