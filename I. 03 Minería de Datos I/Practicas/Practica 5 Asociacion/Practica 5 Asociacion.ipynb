# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from apyori import apriori

# %%
tienda = pd.read_csv('store_data.csv', header=None)
tienda.head(3)
# Out:
#         0          1        2               3             4   \
# 0   shrimp    almonds  avocado  vegetables mix  green grapes
# 1  burgers  meatballs     eggs             NaN           NaN
# 2  chutney        NaN      NaN             NaN           NaN
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# 0  low fat yogurt  green tea  honey  salad  mineral water  salmon
# 1             NaN        NaN    NaN    NaN            NaN     NaN
# 2             NaN        NaN    NaN    NaN            NaN     NaN
#
#                   16               17       18         19
# 0  antioxydant juice  frozen smoothie  spinach  olive oil
# ...

# %%
listas = []
for i in range(len(tienda)):
    listas.append([str(tienda.values[i,j]) for j in range(0, len(tienda.columns))])

# %%
reglasAsociacion = apriori(listas, min_support=0.0045, min_confidence=0.2, min_lift=3, min_length=2)
resultadosAsociacion = list(reglasAsociacion)
print(len(resultadosAsociacion))
# Out:
# 48

# %%
data=[]
columnas=["Rule","Support","Confidence","Lift"]
consolidado=pd.DataFrame()
for item in resultadosAsociacion:
    par = item[0] 
    items = [x for x in par]
    if len(items)==3:
        Rule= items[0] + " -> " + items[1]+ " , " + items[2]
    else:
        Rule= items[0] + " -> " + items[1]
    Support=item[1]
    Confidence=item[2][0][2]
    Lift=item[2][0][3]
    data.append({"Rule":Rule,"Support":Support,"Confidence":Confidence,"Lift":Lift})
    consolidado=pd.DataFrame(data,columns=columnas)
    
consolidado.sort_values(by="Lift", ascending=False).head()
# Out:
#                             Rule   Support  Confidence      Lift
# 0         light cream -> chicken  0.004533    0.290598  4.843951
# 7   nan -> light cream , chicken  0.004533    0.290598  4.843951
# 11       nan -> pasta , escalope  0.005866    0.372881  4.700812
# 2              pasta -> escalope  0.005866    0.372881  4.700812
# 28         nan -> pasta , shrimp  0.005066    0.322034  4.515096
