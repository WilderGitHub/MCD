# %%
import numpy as np
import pandas as pd

# %%
w = pd.read_excel("borrar.xlsx")
w = w.drop(columns="Unnamed: 0")

# %%
ww=w.groupby(w["TNT"])
ww.mean()
# Out:
#      GESTION  MES       NANDINA        PAIS         KILBRU         KILNET  \
# TNT
# 9     2021.0  1.0  8.012200e+08  378.352941   84018.911765   80415.058824
# 10    2021.0  1.0  9.011190e+08  268.000000   22333.714286   22127.142857
# 18    2021.0  1.0  1.201900e+09  105.000000  186000.000000  186000.000000
# 34    2021.0  1.0  8.290767e+08  307.065789  330953.921316  312734.800526
#
#             FINUNI          VALOR
# TNT
# 9     80415.058824  349552.251765
# 10    22127.142857  133599.995714
# 18   186000.000000   75330.000000
# 34   312734.778421  275225.650921

# %%
borrar = pd.read_csv("mtcars.csv")
borrar
borrar.groupby("am").mean()
# Out:
#           mpg       cyl        disp          hp      drat        wt  \
# am
# 0   17.147368  6.947368  290.378947  160.263158  3.286316  3.768895
# 1   24.392308  5.076923  143.530769  126.846154  4.050000  2.411000
#
#          qsec        vs      gear      carb
# am
# 0   18.183158  0.368421  3.210526  2.736842
# 1   17.360000  0.538462  4.384615  2.923077
